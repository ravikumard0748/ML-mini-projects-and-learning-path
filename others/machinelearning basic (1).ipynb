# %%
    from sklearn.datasets import load_iris
data=load_iris()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\ravik\Downloads\irissis\irisiissisi\iris_dataset.csv")

# %%
print(data.shape)
# Out:
# (150, 5)

# %%
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#         target
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
print(data.describe())
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#              target
# ...

# %%
print(data.groupby('target').size()  )
# Out:
# target
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data.plot(kind="box",layout=(2,2),sharex=False,sharey=False,subplots=True)
plt.show()
# data.plot(kind="box",layout=(2,2),sharex=False,sharey=False,subplots=True)

# %% [markdown]
# DONT SHARE X,Y VALUES BECAUSE THE PLOT RANGES WILL VARY WHEN WE SHARE THE X,X IT TAKE THE COMMON X XAND Y AND GRAPH NOT LOOK GRATELY

# %%
data.hist()
plt.show()

# %% [raw]
# THE ABOVE ARE UNI VARIATED PLOTS

# %%
scatter_matrix(data)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import model_selection

# %%
x=data.drop(columns='target')
y=data['target']
x.values,y.values
# Out:
# (array([[5.1, 3.5, 1.4, 0.2],
#         [4.9, 3. , 1.4, 0.2],
#         [4.7, 3.2, 1.3, 0.2],
#         [4.6, 3.1, 1.5, 0.2],
#         [5. , 3.6, 1.4, 0.2],
#         [5.4, 3.9, 1.7, 0.4],
#         [4.6, 3.4, 1.4, 0.3],
#         [5. , 3.4, 1.5, 0.2],
#         [4.4, 2.9, 1.4, 0.2],
#         [4.9, 3.1, 1.5, 0.1],
#         [5.4, 3.7, 1.5, 0.2],
#         [4.8, 3.4, 1.6, 0.2],
#         [4.8, 3. , 1.4, 0.1],
#         [4.3, 3. , 1.1, 0.1],
#         [5.8, 4. , 1.2, 0.2],
#         [5.7, 4.4, 1.5, 0.4],
#         [5.4, 3.9, 1.3, 0.4],
#         [5.1, 3.5, 1.4, 0.3],
#         [5.7, 3.8, 1.7, 0.3],
#         [5.1, 3.8, 1.5, 0.3],
#         [5.4, 3.4, 1.7, 0.2],
#         [5.1, 3.7, 1.5, 0.4],
#         [4.6, 3.6, 1. , 0.2],
#         [5.1, 3.3, 1.7, 0.5],
#         [4.8, 3.4, 1.9, 0.2],
#         [5. , 3. , 1.6, 0.2],
#         [5. , 3.4, 1.6, 0.4],
#         [5.2, 3.5, 1.5, 0.2],
#         [5.2, 3.4, 1.4, 0.2],
#         [4.7, 3.2, 1.6, 0.2],
#         [4.8, 3.1, 1.6, 0.2],
# ...

# %%
seed=6 # when giveing like this it ensure the randomness of the splitting size whenver we splitting the dataset it always give the same result
validation_size=0.20 # it the siize of the data in the datset were it is used for testing and evaltuing the model 
train_x,test_x,train_y,test_y=model_selection.train_test_split(x,y,random_state=seed,test_size=validation_size)

# %%
seed=6
score='accuracy'

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn import

# %%
models=[]
models.append(('LR',LogisticRegression()))
models.append(('LD',LinearDiscriminantAnalysis()))
models.append(('KNN',KNeighborsClassifier()))
models.append(('NB',GaussianNB()))
models.append(('CART',DecisionTreeClassifier()))
models.append(('svm',SVC()))

# %%
results=[]
model=[]
for name,model in models:
    kfold=model_selection.KFold(n_splits=10)
    cv_results=model_selection.cross_val_score(model,train_x,train_y,cv=kfold,scoring=score,max_iter=100)
    results.append(cv_results)
    print(name,cv_results.mean(),cv_results.std())
